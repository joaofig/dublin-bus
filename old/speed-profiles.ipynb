# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df = pd.read_csv('data/speed.csv')

# %%
df.head()
# Out:
#              timestamp  stop_id  at_stop  delay       lon        lat  \
# 0  2013-01-01 00:00:07     3222        1      0 -6.231633  53.317768
# 1  2013-01-01 00:00:27     3222        1      0 -6.231633  53.317768
# 2  2013-01-01 00:00:45     3222        1      0 -6.231650  53.317768
# 3  2013-01-01 00:01:05     3222        1      0 -6.231650  53.317768
# 4  2013-01-01 00:01:25     3222        1      0 -6.231616  53.317768
#
#     flt_lon    flt_lat     speed
# 0 -6.231633  53.317768  0.000000
# 1 -6.231633  53.317768  0.000000
# 2 -6.231647  53.317768  0.122247
# 3 -6.231651  53.317768  0.075909
# 4 -6.231623  53.317768  0.209431

# %%
n_rows = len(df)

# %%
plt.plot(df.index.values, df['at_stop'])
ay2 = plt.twinx()
ay2.plot(df.index.values, df['speed'], 'r')
plt.tight_layout()

# %%
df.corr()
# Out:
#           stop_id   at_stop     delay       lon       lat   flt_lon   flt_lat  \
# stop_id  1.000000  0.488023  0.029391  0.411017 -0.444397  0.411050 -0.444326
# at_stop  0.488023  1.000000 -0.006991 -0.159954  0.036929 -0.159965  0.036905
# delay    0.029391 -0.006991  1.000000  0.083003 -0.047201  0.083049 -0.047138
# lon      0.411017 -0.159954  0.083003  1.000000 -0.947301  0.999991 -0.947240
# lat     -0.444397  0.036929 -0.047201 -0.947301  1.000000 -0.947227  0.999988
# flt_lon  0.411050 -0.159965  0.083049  0.999991 -0.947227  1.000000 -0.947168
# flt_lat -0.444326  0.036905 -0.047138 -0.947240  0.999988 -0.947168  1.000000
# speed   -0.316208 -0.497413  0.070130  0.149847 -0.011811  0.149727 -0.011932
#
#             speed
# stop_id -0.316208
# at_stop -0.497413
# delay    0.070130
# lon      0.149847
# lat     -0.011811
# flt_lon  0.149727
# flt_lat -0.011932
# speed    1.000000
